# %% [markdown]
# **Membaca Karakter Khusus Pada Kalimat Pada Variabel Data Yang Diisi Dengan Data Frame**
#
# Pada hasil data di bawah ini masih terdapat duplikasi symbol pada masing-masing baris kalimat....::

# %%
import pandas as pd
import re

# membuat dataframe contoh
data = {'Tweet': ['Ini adalah tweet pertama! #contoh', 'Ini adalah tweet kedua. :)', 'Ini adalah tweet ketiga, dengan 12345.']}
dfx = pd.DataFrame(data)

#  Membuat lits global untuk menampilkan hasilnya ke samping 
result = []

# mencari karakter khusus selain huruf dan angka pada kolom Tweet dan menghilangkan duplikasinya
karakter_khusus = set()
for tweet in dfx['Tweet']:
    # mencari karakter yang bukan huruf atau angka dalam tweet
    karakter_khusus_tweet = re.findall(r'[^a-zA-Z0-9\s]', tweet)
    # menambahkan karakter khusus pada tweet ke dalam set karakter khusus
    karakter_khusus.update(karakter_khusus_tweet)

# menampilkan karakter khusus yang ditemukan
print("Karakter khusus yang ditemukan:")
for karakter in karakter_khusus:
    list.append(karakter_khusus)
print(list)
# Out:
# Karakter khusus yang ditemukan:
# [{'#', '.', ')', ',', '!', ':'}, {'#', '.', ')', ',', '!', ':'}, {'#', '.', ')', ',', '!', ':'}, {'#', '.', ')', ',', '!', ':'}, {'#', '.', ')', ',', '!', ':'}, {'#', '.', ')', ',', '!', ':'}]

# %% [markdown]
# **Berikut ini kode yang hasil pencariannya tidak terjadi duplikasi simbol**

# %%
import pandas as pd
import re

# membuat dataframe contoh
data = {'Tweet': ['Ini adalah tweet pertama! #contoh', 'Ini adalah tweet kedua. :)', 'Ini adalah tweet ketiga, dengan 12345.']}
dfx = pd.DataFrame(data)

#  Membuat list global untuk menampilkan hasilnya ke samping 
result = []

# mencari karakter khusus selain huruf dan angka pada kolom Tweet dan menghilangkan duplikasinya
karakter_khusus = set()

for tweet in dfx['Tweet']:
    # mencari karakter yang bukan huruf atau angka dalam tweet
    karakter_khusus_tweet = re.findall(r'[^a-zA-Z0-9\s]', tweet)
    # menambahkan karakter khusus pada tweet ke dalam set karakter khusus
    karakter_khusus.update(karakter_khusus_tweet)

# menampilkan karakter khusus yang ditemukan
print("Karakter khusus yang ditemukan:")
for karakter in karakter_khusus:
    result.append(karakter)
    
print(result)
# Out:
# Karakter khusus yang ditemukan:
# ['#', '.', ')', ',', '!', ':']

# %% [markdown]
# **Bagaimana Jika Data Itu Ada Di Dalam Database?**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BINAR GOLD CHALLANGE
# Out:
# /content/drive/MyDrive/Colab Notebooks/BINAR GOLD CHALLANGE

# %%
df = pd.read_csv('data.csv', encoding='latin-1')

# %%
df[['Tweet']]
# Out:
#                                                    Tweet
# 0      - disaat semua cowok berusaha melacak perhatia...
# 1      RT USER: USER siapa yang telat ngasih tau elu?...
# 2      41. Kadang aku berfikir, kenapa aku tetap perc...
# 3      USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...
# 4      USER USER Kaum cebong kapir udah keliatan dong...
# ...                                                  ...
# 13164  USER jangan asal ngomong ndasmu. congor lu yg ...
# 13165                       USER Kasur mana enak kunyuk'
# 13166  USER Hati hati bisu :( .g\n\nlagi bosan huft \...
# 13167  USER USER USER USER Bom yang real mudah terdet...
# 13168  USER Mana situ ngasih(": itu cuma foto ya kuti...
#
# [13169 rows x 1 columns]

# %%
import pandas as pd
import re

#  Membuat list global untuk menampilkan hasilnya ke samping 
result = []

# mencari karakter khusus selain huruf dan angka pada kolom Tweet dan menghilangkan duplikasinya
karakter_khusus = set()

for tweet in df['Tweet']:
    # mencari karakter yang bukan huruf atau angka dalam tweet
    karakter_khusus_tweet = re.findall(r'[^a-zA-Z0-9\s]', tweet)
    # menambahkan karakter khusus pada tweet ke dalam set karakter khusus
    karakter_khusus.update(karakter_khusus_tweet)

# menampilkan karakter khusus yang ditemukan
print("Karakter khusus yang ditemukan:")
for karakter in karakter_khusus:
    result.append(karakter)
    
print(result)
# Out:
# Karakter khusus yang ditemukan:
# ['>', '¸', 'ª', '¨', '/', '_', 'Â', '±', '\\', '=', '³', 'á', '*', ':', '|', '¥', 'ï', '«', '²', '`', 'Ä', '»', '}', '.', '°', '%', 'ë', "'", 'ð', '¢', '¶', 'µ', '·', '^', '-', '(', '¡', '®', '£', ';', '½', '¬', '$', '#', 'Ø', ')', 'Ù', '?', '~', 'â', ']', 'º', 'ê', '!', '¹', '&', '©', '@', '¦', '{', '\xad', '¿', '[', '¯', '"', ',', '¼', 'Ã', '§', '+', '´', 'ã', '¤']
